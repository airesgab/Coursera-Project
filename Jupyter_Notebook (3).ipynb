# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Gabrielle Tomita__
#
# Server

# %% [markdown]
# _Data science has always been a hobby where I had fun, I would like to implement as part of my career._

# %% [markdown]
# ### I will be introducing myself on the next cell

# %%
msg = "A little about me"
print(msg)
# Out:
# A little about me

# %% [markdown]
# * This is me
#
# ![](attachment:https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/jupyterlite/lab?path=IMG_7710.jpg)
#
# * This is my account
#
# [airesgab](https://www.instagram.com/airesgab/?fbclid=IwAR1MQwEbeygV8kD_2HX0cnfg0-pBGwocYcaQf7FQMMy6NcRxMpJBxW8qIgA)
